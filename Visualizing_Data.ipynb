# %% [markdown]
# <a href="https://colab.research.google.com/github/erdebashishsingh/Python-Code/blob/master/Visualizing_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x= [11,12,3,14,10.5]
y = [2010,2011,2012,2013,2014]

plt.plot(y,x ,color = "green" , marker = '*')
